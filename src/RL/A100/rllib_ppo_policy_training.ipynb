# %% [markdown]
# ### Training RL Policies using L5Kit Closed-Loop Environment
#
# This notebook describes how to train RL policies for self-driving using our gym-compatible closed-loop environment.
#
# We will be using [Proximal Policy Optimization (PPO)](https://arxiv.org/abs/1707.06347) algorithm as our reinforcement learning algorithm, as it not only demonstrates remarkable performance but it is also empirically easy to tune.
#
# The PPO implementation in this notebook is based on [Stable Baselines3](https://github.com/DLR-RM/stable-baselines3) framework, a popular framework for training RL policies. Note that our environment is also compatible with [RLlib](https://docs.ray.io/en/latest/rllib.html), another popular frameworks for the same.

# %% [markdown]
# ref:
# ([rllib] Best workflow to train, save, and test agent #9123
# )[https://github.com/ray-project/ray/issues/9123]

# %%
import os
os.environ["L5KIT_DATA_FOLDER"] = '/DATA/l5kit/l5kit-dataset'
# os.environ["TUNE_RESULT_DIR"] =  '/DATA/l5kit/rllib_tb_logs'

# %%
import gym

# from stable_baselines3 import PPO
# from stable_baselines3.common.callbacks import CheckpointCallback
# from stable_baselines3.common.env_util import make_vec_env
# from stable_baselines3.common.utils import get_linear_fn
# from stable_baselines3.common.vec_env import SubprocVecEnv

from l5kit.configs import load_config_data
# from l5kit.environment.feature_extractor import CustomFeatureExtractor
# from l5kit.environment.callbacks import L5KitEvalCallback
from l5kit.environment.envs.l5_env import SimulationConfigGym, GymStepOutput, L5Env

from l5kit.visualization.visualizer.zarr_utils import episode_out_to_visualizer_scene_gym_cle
from l5kit.visualization.visualizer.visualizer import visualize
from bokeh.io import output_notebook, show
from l5kit.environment.gym_metric_set import L2DisplacementYawMetricSet, CLEMetricSet
from prettytable import PrettyTable
import datetime
from ray.rllib.models import ModelCatalog
from ray.rllib.models.torch.torch_modelv2 import TorchModelV2
import torch.nn as nn
import numpy as np
import gym
from typing import Dict
import numpy as np
import ray
import pytz
# Out:
# /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/transforms3d/quaternions.py:26: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   _MAX_FLOAT = np.maximum_sctype(np.float)

# %% [markdown]
# ## Init ray and env

# %%
# ray.init(num_cpus=64, ignore_reinit_error=True, log_to_driver=False)

# %%
# Dataset is assumed to be on the folder specified
# in the L5KIT_DATA_FOLDER environment variable
from l5kit.configs import load_config_data

# get environment config

# env_config_path = '/DATA/l5kit/configs/gym_config.yaml'
env_config_path = '/home/pronton/rl/l5kit/examples/RL/gym_config.yaml'
cfg = load_config_data(env_config_path)

# %% [markdown]
# ## Customize my model

# %%
from ray.rllib.models import ModelCatalog
class GNCNN(TorchModelV2, nn.Module):
    """
    Simple Convolution agent that calculates the required linear output layer
    """

    def __init__(self, obs_space, action_space, num_outputs, model_config, name):
        super().__init__(obs_space, action_space, num_outputs, model_config, name)
        nn.Module.__init__(self)

        # raise ValueError(obs_space.shape)
        self._num_objects = obs_space.shape[2] # num_of_channels of input, size x size x channels
        self._num_actions = num_outputs
        self._feature_dim = model_config["custom_model_config"]['feature_dim']

        self.network = nn.Sequential(
            nn.Conv2d(self._num_objects, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False),
            nn.GroupNorm(4, 64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(64, 32, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False),
            nn.GroupNorm(2, 32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.Linear(in_features=1568, out_features=self._feature_dim),
        )

        self._actor_head = nn.Sequential(
            nn.Linear(self._feature_dim, 256),
            nn.ReLU(),
            nn.Linear(256, self._num_actions),
        )

        self._critic_head = nn.Sequential(
            nn.Linear(self._feature_dim, 1),
        )

    def forward(self, input_dict, state, seq_lens):
        obs_transformed = input_dict['obs'].permute(0, 3, 1, 2) # 32 x 112 x 112 x 7 [B, size, size, channels]
        network_output = self.network(obs_transformed)
        value = self._critic_head(network_output)
        self._value = value.reshape(-1)
        logits = self._actor_head(network_output)
        return logits, state

    def value_function(self):
        return self._value

ModelCatalog.register_custom_model("GN_CNN_torch_model", GNCNN)

# %%
from ray.rllib.models import ModelCatalog
class GNCNN_separated(TorchModelV2, nn.Module):
    """
    Simple Convolution agent that calculates the required linear output layer
    """

    def __init__(self, obs_space, action_space, num_outputs, model_config, name):
        super().__init__(obs_space, action_space, num_outputs, model_config, name)
        nn.Module.__init__(self)

        # raise ValueError(obs_space.shape)
        self._num_objects = obs_space.shape[2] # num_of_channels of input, size x size x channels
        self._num_actions = num_outputs
        self._feature_dim = model_config["custom_model_config"]['feature_dim']

        self._actor_head = nn.Sequential(
            nn.Conv2d(self._num_objects, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False),
            nn.GroupNorm(4, 64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(64, 32, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False),
            nn.GroupNorm(2, 32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.Linear(in_features=1568, out_features=self._feature_dim),
            nn.Linear(self._feature_dim, 256),
            nn.ReLU(),
            nn.Linear(256, self._num_actions),
        )

        self._critic_head = nn.Sequential(
            nn.Conv2d(self._num_objects, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False),
            nn.GroupNorm(4, 64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(64, 32, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False),
            nn.GroupNorm(2, 32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.Linear(in_features=1568, out_features=self._feature_dim),
            nn.Linear(self._feature_dim, 1),
        )

    def forward(self, input_dict, state, seq_lens):
        obs_transformed = input_dict['obs'].permute(0, 3, 1, 2) # 32 x 112 x 112 x 7 [B, size, size, channels]
        # network_output = self.network(obs_transformed)
        value = self._critic_head(obs_transformed)
        self._value = value.reshape(-1)
        logits = self._actor_head(obs_transformed)
        return logits, state

    def value_function(self):
        return self._value
ModelCatalog.register_custom_model(
        "GN_CNN_separated_torch_model", GNCNN_separated
    )

# %% [markdown]
# ## Define Training and Evaluation Environments
#
# **Training**: We will be training the PPO policy on episodes of length 32 time-steps. We will have 4 sub-processes (training environments) that will help to parallelize and speeden up episode rollouts. The *SimConfig* dataclass will define the parameters of the episode rollout: like length of episode rollout, whether to use log-replayed agents or simulated agents etc.
#
# **Evaluation**: We will evaluate the performance of the PPO policy on the *entire* scene (~248 time-steps).

# %% [markdown]
# ## Customize gym env

# %%
class L5EnvWrapper(gym.Wrapper):
    def __init__(self, env, raster_size = 112, n_channels = 7):
        super().__init__(env)
        self.env = env
        self.n_channels = n_channels
        self.raster_size = raster_size
        obs_shape = (self.raster_size, self.raster_size, self.n_channels)
        self.observation_space =gym.spaces.Box(low=0, high=1, shape=obs_shape, dtype=np.float32)

    def step(self, action:  np.ndarray) -> GymStepOutput:
        # return GymStepOutput(obs, reward["total"], done, info)
        output =  self.env.step(action)
        onlyImageState = output.obs['image'].reshape(self.raster_size, self.raster_size, self.n_channels)
        return GymStepOutput(onlyImageState, output.reward, output.done, output.info)

    def reset(self) -> Dict[str, np.ndarray]:
        return self.env.reset()['image'].reshape(self.raster_size, self.raster_size, self.n_channels)

# %%
from ray import tune
train_eps_length = 32
train_sim_cfg = SimulationConfigGym()
train_sim_cfg.num_simulation_steps = train_eps_length + 1


# Register , how your env should be constructed (always with 5, or you can take values from the `config` EnvContext object):
env_kwargs = {'env_config_path': env_config_path, 'use_kinematic': True, 'sim_cfg': train_sim_cfg}

tune.register_env("L5-CLE-V0", lambda config: L5Env(**env_kwargs))
tune.register_env("L5-CLE-V1", lambda config: L5EnvWrapper(env = L5Env(**env_kwargs), \
                                                           raster_size= cfg['raster_params']['raster_size'][0], \
                                                           n_channels = 7))

# %% [markdown]
# ## Train

# %% [markdown]
# ### ref
#
# Resume stop tune: https://docs.ray.io/en/latest/tune/tutorials/tune-stopping.html
#
# tune.Tuner analysis: https://docs.ray.io/en/latest/rllib/rllib-training.html#basic-python-api
#
# get best result, load from dir: https://docs.ray.io/en/master/tune/examples/tune_analyze_results.html#trial-level-analysis-working-with-an-individual-result
#
# ### Hyperparam
# ```
# lr = 3e-4
# num_rollout_steps = 256
# gamma = 0.8
# gae_lambda = 0.9
# n_epochs = 10
# seed = 42
# batch_size = 64
# ```
# ### Clipping schedule of PPO epsilon parameter
# ```
# start_val = 0.1
# end_val = 0.01
# training_progress_ratio = 1.0
# clip_schedule = get_linear_fn(start_val, end_val, training_progress_ratio)
# ```

# %%
# !wandb login 083592c84134c040dcca598c644c348d32540a08

# %%
import numpy as np

import ray
from ray import air, tune
from ray.air import session
from ray.air.integrations.wandb import setup_wandb
from ray.air.integrations.wandb import WandbLoggerCallback
os.environ['WANDB_NOTEBOOK_NAME'] = '/DATA/rllib_ppo_policy_training.ipynb'
os.environ["WANDB_API_KEY"] = '083592c84134c040dcca598c644c348d32540a08'

# %%
import wandb
wandb.init(project="l5kit2", reinit = True)

# %% [markdown]
# ### shared polocy

# %%
import ray
from ray import air, tune

train_envs = 4
hcmTz = pytz.timezone("Asia/Ho_Chi_Minh") 
date = datetime.datetime.now(hcmTz).strftime("%d-%m-%Y_%H-%M-%S")
ray_result_logdir = '/DATA/l5kit/ray_results/' + date

config_param_space = {
    "env": "L5-CLE-V1",
    "framework": "torch",
    "num_gpus": 1,
    "num_workers": 63,
    "num_envs_per_worker": train_envs,
    'num_sgd_iter': 5,
    'sgd_minibatch_size': 256,
    # 'num_cpus_per_worker': 0,  # This avoids running out of resources in the notebook environment when this cell is re-executed
    "model": {
        "custom_model": "GN_CNN_torch_model",
        "custom_model_config": {'feature_dim':128},
    },
    
    '_disable_preprocessor_api': True,
     "eager_tracing": True,
     "restart_failed_sub_environments": True,
    "lr": 0.0003,
    "gamma": 0.8,
    'seed': 42,
}

result_grid = tune.Tuner(
    "PPO",
    run_config=air.RunConfig(
        stop={"episode_reward_mean": 0, 'timesteps_total': int(6e6)},
        local_dir=ray_result_logdir,
        checkpoint_config=air.CheckpointConfig(num_to_keep=4, checkpoint_frequency = 10, checkpoint_score_attribute = 'episode_reward_mean')
        ),
    param_space=config_param_space).fit()

# %%
import ray
from ray import air, tune
hcmTz = pytz.timezone("Asia/Ho_Chi_Minh") 
date = datetime.datetime.now(hcmTz).strftime("%d-%m-%Y_%H-%M-%S")
ray_result_logdir = '/DATA/l5kit/ray_results/' + date

train_envs = 4
lr = 3e-3
lr_start = 3e-4
lr_end = 3e-5
lr_time = int(4e6)

config_param_space = {
    "env": "L5-CLE-V1",
    "framework": "torch",
    "num_gpus": 1,
    "num_workers": 63,
    "num_envs_per_worker": train_envs,
    "model": {
        "custom_model": "GN_CNN_torch_model",
        "custom_model_config": {'feature_dim':128},
    },
    
    '_disable_preprocessor_api': True,
     "eager_tracing": True,
     "restart_failed_sub_environments": True,
    "lr": lr,
    'seed': 42,
    "lr_schedule": [
        [1e6, lr_start],
        [2e6, lr_end],
    ],
    'train_batch_size': 8000,
    'sgd_minibatch_size': 1024,
    'num_sgd_iter': 16,
    'seed': 42,
    'batch_mode': 'truncate_episodes',
    "rollout_fragment_length": 32,
    'gamma': 0.8,    
}

result_grid = tune.Tuner(
    "PPO",
    run_config=air.RunConfig(
        stop={"episode_reward_mean": 0, 'timesteps_total': int(6e6)},
        local_dir=ray_result_logdir,
        checkpoint_config=air.CheckpointConfig(num_to_keep=4, 
                                               checkpoint_frequency = 10, 
                                               checkpoint_score_attribute = 'episode_reward_mean'),
        callbacks=[WandbLoggerCallback(project="l5kit2", save_checkpoints=True),],
        ),
    param_space=config_param_space).fit()

# %%
config_param_space['lr'] = 3e-5
path_to_trained_agent_checkpoint = 'l5kit/ray_results/27-12-2022_16-24-37/PPO/PPO_L5-CLE-V1_fdd0f_00000_0_2022-12-27_11-45-42/checkpoint_000480'
from ray.rllib.algorithms.ppo import PPO
ray.tune.run(PPO, config=config_param_space, restore=path_to_trained_agent_checkpoint)

# %%
import ray
from ray import air, tune
ray_result_logdir = '/DATA/l5kit/ray_results'
config_param_space = {
    "env": "L5-CLE-V1",
    "framework": "torch",
    "num_gpus": 1,
    "num_workers": 63,
    'train_batch_size': 4000,
    'sgd_minibatch_size': 4096,
    "num_envs_per_worker": 32,
    'num_sgd_iter': 32,
    'sgd_minibatch_size': 256,
    # 'num_cpus_per_worker': 0,  # This avoids running out of resources in the notebook environment when this cell is re-executed
    "model": {
        "custom_model": "GN_CNN_torch_model",
        "custom_model_config": {'feature_dim':128},
    },
    
    '_disable_preprocessor_api': True,
     "eager_tracing": True,
     # "log_level": "DEBUG",
     "restart_failed_sub_environments": True,
    "lr": 0.0003,
    "gamma": 0.8,
    'seed': 42,
}

result_grid = tune.Tuner(
    "PPO",
    run_config=air.RunConfig(
        stop={"episode_reward_mean": -30, 'timesteps_total': int(12e6)},
        local_dir=ray_result_logdir,
        checkpoint_config=air.CheckpointConfig(num_to_keep=4, checkpoint_frequency = 10, checkpoint_score_attribute = 'episode_reward_mean')
        ),
    param_space=config_param_space).fit()

# %%
ray_result_logdir = '/DATA/l5kit/ray_results'

tuner = tune.Tuner.restore(
    path=ray_result_logdir + '/PPO',
)
result_grid = tuner.fit()

# %%
result_grid

# Get the result with the maximum test set `mean_accuracy`
best_result = result_grid.get_best_result()
best_result.checkpoint

# %%
best_result.metrics

# %%
result_df = best_result.metrics_dataframe
result_df[['num_agent_steps_sampled','episode_reward_mean'] ]

# %%
best_result.metrics_dataframe.plot("num_agent_steps_sampled", "episode_reward_mean")

# %%
for result in result_grid:
    print(1)

# %% [markdown]
# ### Separated policy

# %%
import ray
from ray import air, tune
train_envs = 4
ray_result_logdir = '/DATA/l5kit/ray_results'
lr = 3e-3
lr_start = 3e-4
lr_end = 3e-5
lr_time = int(4e6)

config_param_space = {
    "env": "L5-CLE-V1",
    "framework": "torch",
    "num_gpus": 1,
    "num_workers": 63,
    "num_envs_per_worker": train_envs,
    '_disable_preprocessor_api': True,
    "eager_tracing": True,
    "restart_failed_sub_environments": True,
    "lr": lr_start,
    # "model": {
    #     "custom_model": "GN_CNN_separated_torch_model",
    #     "custom_model_config": {'feature_dim':128},
    # },
    'model' : {
            "dim": 84,
            # "conv_filters" : [[64, [7,7], 3], [32, [11,11], 3], [32, [11,11], 3]],
            "conv_activation": "relu",
            "post_fcnet_hiddens": [256],
            "post_fcnet_activation": "relu",
            "vf_share_layers": False,   
    },
#
    "lr": lr,
    'seed': 42,
    "lr_schedule": [
        [1e6, lr_start],
        [2e6, lr_end],
    ],
    'train_batch_size': 8000,
    'sgd_minibatch_size': 256,
    'num_sgd_iter': 16,
    'seed': 42,
    'batch_mode': 'truncate_episodes',
    "rollout_fragment_length": 32,
    'gamma': 0.8,
}

result_grid = tune.Tuner(
    "PPO",
    run_config=air.RunConfig(
        stop={"episode_reward_mean": 0, 'timesteps_total': int(6e6)},
        local_dir=ray_result_logdir,
        checkpoint_config=air.CheckpointConfig(num_to_keep=4, checkpoint_frequency = 10, checkpoint_score_attribute = 'episode_reward_mean'),
        callbacks=[WandbLoggerCallback(project="l5kit2", save_checkpoints=True),],
        ),
    param_space=config_param_space).fit()

# %%
ray_result_logdir = '/DATA/l5kit/ray_results'

tuner = tune.Tuner.restore(
    path=ray_result_logdir + '/PPO',
)
tuner.fit()

# %% [markdown]
# NOTE: Experiment has been interrupted, but the most recent state was saved. You can continue running this experiment by passing `resume=True` to `tune.run()`
#
# 2022-12-04 05:50:38,570	INFO experiment_analysis.py:795 -- No `self.trials`. Drawing logdirs from checkpoint file. This may result in some information that is out of sync, as checkpointing is periodic.
#
# 2022-12-04 05:50:39,684	INFO trial_runner.py:601 -- A local experiment checkpoint was found and will be used to restore the previous experiment state.
# 2022-12-04 05:50:39,687	INFO trial_runner.py:738 -- Using following checkpoint to resume: /content/drive/MyDrive/Colab Notebooks/l5kit/ray_results/PPO/experiment_state-2022-12-04_05-28-55.json
#
# 2022-12-04 05:50:39,710	WARNING trial_runner.py:743 -- Attempting to resume experiment from /content/drive/MyDrive/Colab Notebooks/l5kit/ray_results/PPO. This will ignore any new changes to the specification.
#
# 2022-12-04 05:50:40,703	INFO tune.py:668 -- TrialRunner resumed, ignoring new add_experiment but updating trial resources.

# %% [markdown]
# **Voila!** We have a trained PPO policy! Train for larger number of steps for better accuracy. Typical RL algorithms require training atleast 1M steps for good convergence. You can visualize the quantitiative evaluation using tensorboard.

# %% [markdown]
# ## Visualize the episode from the environment
#
# We can easily visualize the outputs obtained by rolling out episodes in the L5Kit using the Bokeh visualizer.

# %%
config_param_space = {
    # "env": "L5-CLE-V1",
    "framework": "torch",
    "num_gpus": 0,
    "num_workers": 1,
    "num_envs_per_worker": 1,
    "model": {
        "custom_model": "GN_CNN_torch_model",
        "custom_model_config": {'feature_dim':128},
    },  
}

# %%
from ray import tune
rollout_sim_cfg = SimulationConfigGym()
rollout_sim_cfg.num_simulation_steps = None


# Register , how your env should be constructed (always with 5, or you can take values from the `config` EnvContext object):

env_kwargs = {'env_config_path': env_config_path, 'use_kinematic': True, 'sim_cfg': rollout_sim_cfg,  'train': False, 'return_info': True}

rollout_env = L5EnvWrapper(L5Env(**env_kwargs))
tune.register_env("L5-CLE-V2", lambda config: L5EnvWrapper(env = L5Env(**env_kwargs), \
                                                           raster_size= cfg['raster_params']['raster_size'][0], \
                                                           n_channels = 7))
# Out:
# /home/pronton/rl/l5kit/l5kit/l5kit/data/map_api.py:399: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   lanes_bounds = np.empty((0, 2, 2), dtype=np.float)  # [(X_MIN, Y_MIN), (X_MAX, Y_MAX)]

# %%
from ray.rllib.algorithms.ppo import PPO
checkpoint_path = 'PPO/PPO_L5-CLE-V1_802de_00000_0_2022-12-31_16-45-15/checkpoint_000400'
algo = PPO(config=config_param_space, env='L5-CLE-V2')
algo.restore(checkpoint_path)
# Out:
# 2023-01-02 14:30:16,390	WARNING deprecation.py:47 -- DeprecationWarning: `algo = Algorithm(env='L5-CLE-V2', ...)` has been deprecated. Use `algo = AlgorithmConfig().environment('L5-CLE-V2').build()` instead. This will raise an error in the future!
# (RolloutWorker pid=33352) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/transforms3d/quaternions.py:26: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=33352) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=33352)   _MAX_FLOAT = np.maximum_sctype(np.float)
# (RolloutWorker pid=33352) /home/pronton/rl/l5kit/l5kit/l5kit/data/map_api.py:399: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=33352) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=33352)   lanes_bounds = np.empty((0, 2, 2), dtype=np.float)  # [(X_MIN, Y_MIN), (X_MAX, Y_MAX)]
# (RolloutWorker pid=33352) 2023-01-02 14:30:25,310	WARNING env.py:147 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=33352) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/gym/utils/seeding.py:47: DeprecationWarning: WARN: Function `rng.randint(low, [high, size, dtype])` is marked as deprecated and will be removed in the future. Please use `rng.integers(low, [high, size, dtype])` instead.
# (RolloutWorker pid=33352)   deprecation(
# (RolloutWorker pid=33352) /home/pronton/rl/l5kit/l5kit/l5kit/data/zarr_dataset.py:213: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=33352)   dataset = ChunkedDataset("")
# (RolloutWorker pid=33352) /home/pronton/rl/l5kit/l5kit/l5kit/simulation/utils.py:107: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=33352)   new_dataset = ChunkedDataset("")
# (RolloutWorker pid=33352) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:71: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=33352) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=33352)   coords = coords.astype(np.int)
# (RolloutWorker pid=33352) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:140: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# (RolloutWorker pid=33352) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=33352)   lanes_mask: Dict[str, np.ndarray] = defaultdict(lambda: np.zeros(len(lane_indices) * 2, dtype=np.bool))
# (RolloutWorker pid=33352) 2023-01-02 14:30:25,525	WARNING catalog.py:637 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# 2023-01-02 14:30:25,712	WARNING catalog.py:637 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# 2023-01-02 14:30:25,819	WARNING util.py:66 -- Install gputil for GPU system monitoring.
# 2023-01-02 14:30:25,863	INFO trainable.py:790 -- Restored on 192.168.1.4 from checkpoint: PPO/PPO_L5-CLE-V1_802de_00000_0_2022-12-31_16-45-15/checkpoint_000400
# 2023-01-02 14:30:25,864	INFO trainable.py:799 -- Current state after restoring: {'_iteration': 400, '_timesteps_total': None, '_time_total': 11514.728887557983, '_episodes_total': 103824}

# %%
def rollout_episode(model, env, idx = 0):
    """Rollout a particular scene index and return the simulation output.

    :param model: the RL policy
    :param env: the gym environment
    :param idx: the scene index to be rolled out
    :return: the episode output of the rolled out scene
    """

    # Set the reset_scene_id to 'idx'
    env.set_reset_id(idx)
    
    # Rollout step-by-step
    obs = env.reset()
    done = False
    while True:
        action = model.compute_single_action(obs, deterministic=True)
        obs, _, done, info = env.step(action)
        if done:
            break

    # The episode outputs are present in the key "sim_outs"
    sim_out = info["sim_outs"][0]
    return sim_out

# Rollout one episode
# sim_out = rollout_episode(model, rollout_env)
# Rollout 5 episodes
sim_outs =[]
for i in range(100):
    sim_outs.append(rollout_episode(algo, rollout_env, i))

# %%
# might change with different rasterizer
map_API = rollout_env.dataset.rasterizer.sem_rast.mapAPI

def visualize_outputs(sim_outs, map_API):
    for sim_out in sim_outs: # for each scene
        vis_in = episode_out_to_visualizer_scene_gym_cle(sim_out, map_API)
        show(visualize(sim_out.scene_id, vis_in))

output_notebook()
visualize_outputs(sim_outs, map_API)

# %% [markdown]
# ## Calculate the performance metrics from the episode outputs
#
# We can also calculate the various quantitative metrics on the rolled out episode output.

# %%
def quantify_outputs(sim_outs, metric_set=None):
    metric_set = metric_set if metric_set is not None else L2DisplacementYawMetricSet()

    metric_set.evaluate(sim_outs)
    scene_results = metric_set.evaluator.scene_metric_results
    fields = ["scene_id", "FDE", "ADE"]
    table = PrettyTable(field_names=fields)
    tot_fde = 0.0
    tot_ade = 0.0
    for scene_id in scene_results:
        scene_metrics = scene_results[scene_id]
        ade_error = scene_metrics["displacement_error_l2"][1:].mean()
        fde_error = scene_metrics['displacement_error_l2'][-1]
        table.add_row([scene_id, round(fde_error.item(), 4), round(ade_error.item(), 4)])
        tot_fde += fde_error.item()
        tot_ade += ade_error.item()

    ave_fde = tot_fde / len(scene_results)
    ave_ade = tot_ade / len(scene_results)
    table.add_row(["Overall", round(ave_fde, 4), round(ave_ade, 4)])
    print(table)


quantify_outputs(sim_outs)
# Out:
# +----------+-----------+----------+
# | scene_id |    FDE    |   ADE    |
# +----------+-----------+----------+
# |    0     |  157.7995 | 65.1411  |
# |    1     |  105.0931 |  13.838  |
# |    2     |  41.1708  | 27.8895  |
# |    3     |  101.7658 | 34.8665  |
# |    4     |  72.3946  |  39.894  |
# |    5     |  63.0206  | 36.3872  |
# |    6     |  168.1008 | 100.4978 |
# |    7     |   70.673  | 25.6934  |
# |    8     |  459.0244 | 153.0358 |
# |    9     |  240.2169 | 89.8288  |
# |    10    |  168.4068 |  64.66   |
# |    11    |  56.8851  | 23.4586  |
# |    12    |  11.4298  | 18.5181  |
# |    13    |  110.5223 | 38.9221  |
# |    14    |  268.5373 | 65.4342  |
# |    15    |  41.7428  | 23.5269  |
# |    16    |  76.9464  | 33.5238  |
# |    17    |  152.1209 | 59.0647  |
# |    18    |  312.4446 | 133.2104 |
# |    19    |  38.9097  | 12.2915  |
# |    20    |  96.1271  | 39.2933  |
# |    21    |   6.7231  |  2.3344  |
# |    22    |   51.412  | 19.2402  |
# |    23    |  164.6095 | 38.3986  |
# |    24    |  38.5561  | 14.2984  |
# |    25    |  497.3426 | 141.657  |
# |    26    |   24.565  |  6.7366  |
# |    27    |  88.2247  | 43.6807  |
# |    28    |  207.4266 | 83.1662  |
# |    29    |  93.3556  | 32.6231  |
# |    30    |  197.0923 | 75.3489  |
# |    31    |   2.9658  |  4.4808  |
# |    32    |  43.4758  | 19.2571  |
# |    33    |  37.5933  |  7.7069  |
# |    34    | 1352.6498 | 228.3172 |
# |    35    |   5.9384  |  7.7163  |
# |    36    |  22.3748  |  7.039   |
# |    37    |  24.5761  | 13.2134  |
# |    38    |  14.8066  |  6.5992  |
# |    39    |  262.065  | 84.6961  |
# |    40    |  240.5224 | 96.6535  |
# |    41    |  141.7705 | 58.0312  |
# |    42    |  67.7056  | 33.9118  |
# |    43    |  71.5291  | 16.9185  |
# |    44    |   32.186  | 18.0167  |
# |    45    |  42.8869  | 33.7899  |
# |    46    |   0.6046  |  5.357   |
# |    47    |  85.6609  | 24.3423  |
# |    48    |  53.4446  | 45.1645  |
# |    49    |  41.6583  | 16.2492  |
# |    50    |  86.9349  | 28.8248  |
# |    51    |  72.3819  | 33.0342  |
# |    52    |   65.236  | 13.1539  |
# |    53    |  32.1877  | 60.9389  |
# |    54    |  140.6257 | 42.4864  |
# |    55    |  158.8698 | 68.3538  |
# |    56    |  18.5533  | 15.2312  |
# |    57    |  230.6595 | 54.3642  |
# |    58    |  44.1316  |  8.4788  |
# |    59    |  43.1626  | 26.0143  |
# |    60    |  389.9129 | 122.6144 |
# |    61    |  26.7373  |  7.258   |
# |    62    |   7.4348  | 24.5859  |
# |    63    |  142.8092 | 41.7402  |
# |    64    |  11.4318  | 10.6764  |
# |    65    |  23.3251  |  16.458  |
# |    66    |  13.2207  |  8.0667  |
# |    67    |   56.303  | 29.7237  |
# |    68    |   5.3667  | 12.8708  |
# |    69    |  151.8578 | 69.8926  |
# |    70    |   20.781  | 12.3606  |
# |    71    |   51.942  | 24.9461  |
# |    72    |  24.6351  |  7.5919  |
# |    73    |  68.6529  | 18.2791  |
# |    74    |  133.3818 | 33.0491  |
# |    75    |  18.5505  | 26.0461  |
# |    76    |  45.6693  | 32.7337  |
# |    77    |  205.7242 | 78.2271  |
# |    78    |  130.7306 | 16.0715  |
# |    79    |  117.6923 | 57.1445  |
# |    80    |  104.9834 | 24.5049  |
# |    81    |  74.7167  | 26.0449  |
# |    82    |  644.1782 | 274.9049 |
# |    83    |  65.3337  | 24.9102  |
# |    84    |  507.6699 | 102.9232 |
# |    85    |  54.2556  | 14.9063  |
# |    86    |  47.1182  | 26.1921  |
# |    87    |  13.1927  |  8.5717  |
# |    88    |  70.5532  |  27.089  |
# |    89    |  147.0591 | 46.2118  |
# |    90    |  51.5839  | 21.0783  |
# |    91    |  91.0647  | 31.8924  |
# |    92    |   9.1853  | 11.3885  |
# |    93    |  306.7982 | 128.2457 |
# |    94    |  59.4127  | 39.8936  |
# |    95    |   92.044  | 59.5356  |
# |    96    |  61.5962  | 14.5757  |
# |    97    |  189.2221 | 177.0583 |
# |    98    |  111.2096 | 30.3021  |
# |    99    |  26.4995  | 20.8429  |
# | Overall  |  119.9363 | 43.9621  |
# +----------+-----------+----------+

# %%
def quantify_outputs(sim_outs, metric_set=None):
    metric_set = metric_set if metric_set is not None else CLEMetricSet()

    metric_set.evaluate(sim_outs)
    scene_results = metric_set.evaluator.scene_metric_results
    fields = ["scene_id", "FDE", "ADE", "DRT", "CF", "CR", "CS", "PEGO"]
    table = PrettyTable(field_names=fields)
    tot_fde = 0.0
    tot_ade = 0.0
    tot_drt = 0.0
    tot_cf = 0.0
    tot_cr = 0.0
    tot_cs = 0.0
    tot_p_ego = 0.0
    tot_a_ego = 0.0
    # print(scene_results[0])
    for scene_id in scene_results:
        scene_metrics = scene_results[scene_id]
        ade_error = scene_metrics["displacement_error_l2"][1:].mean()
        fde_error = scene_metrics['displacement_error_l2'][-1]
        drt_error = scene_metrics['distance_to_reference_trajectory'][-1]
        cf_error = scene_metrics['collision_front'][-1]
        cr_error = scene_metrics['collision_rear'][-1]
        cs_error = scene_metrics['collision_side'][-1]
        p_ego = scene_metrics['simulated_minus_recorded_ego_speed'][-1]
        # a_ego = scene_metrics['aggressive_ego'][-1]
        table.add_row([scene_id, round(fde_error.item(), 4), round(ade_error.item(), 4), round(drt_error.item(), 4), round(cf_error.item(), 4), round(cr_error.item(), 4), 
        round(cs_error.item(), 4), round(p_ego.item(), 4)])
        tot_fde += fde_error.item()
        tot_ade += ade_error.item()
        tot_drt += drt_error.item()
        tot_cf += cf_error.item()
        tot_cr += cr_error.item()
        tot_cs += cs_error.item()
        tot_p_ego += p_ego.item()
        # tot_a_ego += a_ego.item()

    ave_fde = tot_fde / len(scene_results)
    ave_ade = tot_ade / len(scene_results)
    ave_drt = tot_drt / len(scene_results)
    ave_cf = tot_cf / len(scene_results)
    ave_cr = tot_cr / len(scene_results)
    ave_cs = tot_cs / len(scene_results)
    ave_p_ego = tot_p_ego / len(scene_results)
    # ave_a_ego = tot_a_ego / len(scene_results)
    table.add_row(["Overall", round(ave_fde, 4), round(ave_ade, 4), round(ave_drt, 4), round(ave_cf, 4), round(ave_cr, 4), round(ave_cs, 4), round(ave_p_ego, 4)])
    print(table)


quantify_outputs(sim_outs)
# Out:
# +----------+-----------+----------+----------+------+-----+------+----------+
# | scene_id |    FDE    |   ADE    |   DRT    |  CF  |  CR |  CS  |   PEGO   |
# +----------+-----------+----------+----------+------+-----+------+----------+
# |    0     |  157.7995 | 65.1411  |  0.186   | 0.0  | 0.0 | 0.0  | -6.8703  |
# |    1     |  105.0931 |  13.838  |  4.8925  | 0.0  | 0.0 | 0.0  | 35.0033  |
# |    2     |  41.1708  | 27.8895  | 52.3493  | 0.0  | 0.0 | 0.0  |  2.7801  |
# |    3     |  101.7658 | 34.8665  |  58.636  | 0.0  | 0.0 | 0.0  | 12.8634  |
# |    4     |  72.3946  |  39.894  | 74.3069  | 0.0  | 0.0 | 0.0  | 16.1995  |
# |    5     |  63.0206  | 36.3872  | 66.4857  | 0.0  | 0.0 | 0.0  |  2.6412  |
# |    6     |  168.1008 | 100.4978 |  2.3034  | 0.0  | 0.0 | 0.0  |  4.1674  |
# |    7     |   70.673  | 25.6934  |  0.5613  | 0.0  | 0.0 | 0.0  |  3.0076  |
# |    8     |  459.0244 | 153.0358 | 240.2603 | 0.0  | 0.0 | 0.0  | 23.8674  |
# |    9     |  240.2169 | 89.8288  |  0.1423  | 0.0  | 0.0 | 0.0  | -2.4902  |
# |    10    |  168.4068 |  64.66   |  0.4753  | 0.0  | 0.0 | 0.0  | -2.0868  |
# |    11    |  56.8851  | 23.4586  |  0.4925  | 0.0  | 0.0 | 0.0  |  1.112   |
# |    12    |  11.4298  | 18.5181  | 23.7516  | 1.0  | 0.0 | 0.0  |  3.597   |
# |    13    |  110.5223 | 38.9221  | 49.2458  | 0.0  | 0.0 | 0.0  | -4.3969  |
# |    14    |  268.5373 | 65.4342  | 104.8029 | 0.0  | 0.0 | 0.0  | 34.2874  |
# |    15    |  41.7428  | 23.5269  |  3.9479  | 0.0  | 0.0 | 0.0  | -0.2695  |
# |    16    |  76.9464  | 33.5238  |  0.4977  | 0.0  | 0.0 | 0.0  | -1.4281  |
# |    17    |  152.1209 | 59.0647  | 108.4586 | 0.0  | 0.0 | 0.0  |  9.3312  |
# |    18    |  312.4446 | 133.2104 | 40.6073  | 0.0  | 0.0 | 0.0  | -11.5082 |
# |    19    |  38.9097  | 12.2915  |  0.1559  | 0.0  | 0.0 | 0.0  |  1.2466  |
# |    20    |  96.1271  | 39.2933  |  0.4227  | 0.0  | 0.0 | 0.0  |  -6.247  |
# |    21    |   6.7231  |  2.3344  |  0.1426  | 0.0  | 0.0 | 0.0  |  -0.081  |
# |    22    |   51.412  | 19.2402  |  2.0865  | 0.0  | 0.0 | 0.0  | -3.9944  |
# |    23    |  164.6095 | 38.3986  | 61.6692  | 0.0  | 0.0 | 0.0  | 23.2977  |
# |    24    |  38.5561  | 14.2984  |  37.209  | 0.0  | 0.0 | 0.0  | 19.1079  |
# |    25    |  497.3426 | 141.657  | 240.9683 | 0.0  | 0.0 | 0.0  | 76.8447  |
# |    26    |   24.565  |  6.7366  | 13.2288  | 0.0  | 0.0 | 1.0  |  0.303   |
# |    27    |  88.2247  | 43.6807  | 86.8665  | 0.0  | 0.0 | 0.0  |  2.4859  |
# |    28    |  207.4266 | 83.1662  | 10.1023  | 0.0  | 0.0 | 0.0  | -8.7925  |
# |    29    |  93.3556  | 32.6231  | 67.7544  | 0.0  | 0.0 | 0.0  |  5.7297  |
# |    30    |  197.0923 | 75.3489  |  1.8079  | 0.0  | 0.0 | 0.0  | -9.7663  |
# |    31    |   2.9658  |  4.4808  |  0.0566  | 0.0  | 0.0 | 0.0  |  3.536   |
# |    32    |  43.4758  | 19.2571  | 35.8713  | 0.0  | 0.0 | 0.0  |  1.1315  |
# |    33    |  37.5933  |  7.7069  | 10.3617  | 0.0  | 0.0 | 0.0  |  7.5574  |
# |    34    | 1352.6498 | 228.3172 | 423.5244 | 0.0  | 0.0 | 0.0  | 184.4599 |
# |    35    |   5.9384  |  7.7163  |  0.4697  | 0.0  | 0.0 | 0.0  |  1.0326  |
# |    36    |  22.3748  |  7.039   |  0.8148  | 0.0  | 0.0 | 1.0  | -2.5187  |
# |    37    |  24.5761  | 13.2134  |  0.667   | 0.0  | 0.0 | 0.0  |  0.1432  |
# |    38    |  14.8066  |  6.5992  |  0.0889  | 0.0  | 0.0 | 1.0  | -5.3393  |
# |    39    |  262.065  | 84.6961  | 155.5526 | 0.0  | 0.0 | 0.0  |  17.896  |
# |    40    |  240.5224 | 96.6535  | 39.4958  | 0.0  | 0.0 | 0.0  | -4.7345  |
# |    41    |  141.7705 | 58.0312  |  1.9854  | 0.0  | 0.0 | 0.0  | -5.4983  |
# |    42    |  67.7056  | 33.9118  |  2.7714  | 0.0  | 0.0 | 0.0  |  0.7835  |
# |    43    |  71.5291  | 16.9185  |  2.5198  | 0.0  | 0.0 | 0.0  | -10.0291 |
# |    44    |   32.186  | 18.0167  |  0.4137  | 0.0  | 0.0 | 1.0  | 14.5517  |
# |    45    |  42.8869  | 33.7899  |  3.0101  | 0.0  | 0.0 | 0.0  | -1.3962  |
# |    46    |   0.6046  |  5.357   |  0.3912  | 0.0  | 0.0 | 0.0  |  0.2361  |
# |    47    |  85.6609  | 24.3423  | 27.7696  | 0.0  | 0.0 | 0.0  | -2.4215  |
# |    48    |  53.4446  | 45.1645  | 12.9917  | 0.0  | 0.0 | 0.0  | -4.3119  |
# |    49    |  41.6583  | 16.2492  |  0.7279  | 0.0  | 0.0 | 1.0  | -2.5256  |
# |    50    |  86.9349  | 28.8248  |  0.4466  | 0.0  | 0.0 | 0.0  | -5.0538  |
# |    51    |  72.3819  | 33.0342  |  0.6272  | 0.0  | 0.0 | 0.0  | -2.7328  |
# |    52    |   65.236  | 13.1539  | 26.4644  | 0.0  | 0.0 | 0.0  |  7.5112  |
# |    53    |  32.1877  | 60.9389  | 125.831  | 0.0  | 0.0 | 0.0  |   50.9   |
# |    54    |  140.6257 | 42.4864  | 21.3736  | 0.0  | 0.0 | 0.0  | 36.3496  |
# |    55    |  158.8698 | 68.3538  | 91.6531  | 0.0  | 0.0 | 0.0  | -3.6397  |
# |    56    |  18.5533  | 15.2312  |  0.3846  | 0.0  | 0.0 | 0.0  | -1.7004  |
# |    57    |  230.6595 | 54.3642  | 112.074  | 0.0  | 0.0 | 0.0  |  4.7663  |
# |    58    |  44.1316  |  8.4788  |  0.2287  | 0.0  | 0.0 | 0.0  |  -8.065  |
# |    59    |  43.1626  | 26.0143  | 19.8822  | 0.0  | 0.0 | 1.0  | -4.3089  |
# |    60    |  389.9129 | 122.6144 | 278.5757 | 0.0  | 0.0 | 0.0  |  5.026   |
# |    61    |  26.7373  |  7.258   |  0.3189  | 0.0  | 0.0 | 0.0  | -6.1765  |
# |    62    |   7.4348  | 24.5859  |  1.1592  | 0.0  | 0.0 | 0.0  |  -6.752  |
# |    63    |  142.8092 | 41.7402  |  1.1212  | 0.0  | 0.0 | 0.0  | -10.8633 |
# |    64    |  11.4318  | 10.6764  |  0.5548  | 0.0  | 0.0 | 0.0  | -1.4023  |
# |    65    |  23.3251  |  16.458  |  0.8063  | 0.0  | 0.0 | 1.0  | -0.7897  |
# |    66    |  13.2207  |  8.0667  |  0.6128  | 0.0  | 0.0 | 0.0  |  2.6373  |
# |    67    |   56.303  | 29.7237  | 45.2529  | 0.0  | 0.0 | 0.0  |  2.8141  |
# |    68    |   5.3667  | 12.8708  |  9.3536  | 0.0  | 0.0 | 0.0  |  2.7492  |
# |    69    |  151.8578 | 69.8926  | 107.5416 | 0.0  | 0.0 | 0.0  | -6.1663  |
# |    70    |   20.781  | 12.3606  |  0.5843  | 0.0  | 0.0 | 0.0  |  0.1394  |
# |    71    |   51.942  | 24.9461  |  0.5065  | 0.0  | 0.0 | 0.0  | -3.1023  |
# |    72    |  24.6351  |  7.5919  |  0.6289  | 0.0  | 0.0 | 1.0  | -3.1363  |
# |    73    |  68.6529  | 18.2791  |  0.4553  | 0.0  | 0.0 | 0.0  | -6.9842  |
# |    74    |  133.3818 | 33.0491  | 68.4817  | 0.0  | 0.0 | 0.0  |  3.9491  |
# |    75    |  18.5505  | 26.0461  |  3.1614  | 0.0  | 0.0 | 0.0  |  7.0545  |
# |    76    |  45.6693  | 32.7337  |  0.461   | 0.0  | 0.0 | 0.0  |  2.346   |
# |    77    |  205.7242 | 78.2271  |  9.3034  | 0.0  | 0.0 | 0.0  | -10.8685 |
# |    78    |  130.7306 | 16.0715  | 18.1714  | 0.0  | 0.0 | 0.0  | 40.9957  |
# |    79    |  117.6923 | 57.1445  | 109.7584 | 0.0  | 0.0 | 0.0  | -2.4681  |
# |    80    |  104.9834 | 24.5049  |  4.5881  | 0.0  | 0.0 | 0.0  |  -7.32   |
# |    81    |  74.7167  | 26.0449  |  0.5411  | 0.0  | 0.0 | 0.0  |  -6.63   |
# |    82    |  644.1782 | 274.9049 | 559.601  | 0.0  | 0.0 | 0.0  | 28.1429  |
# |    83    |  65.3337  | 24.9102  |  0.246   | 0.0  | 0.0 | 0.0  | -3.8668  |
# |    84    |  507.6699 | 102.9232 | 199.8582 | 0.0  | 0.0 | 0.0  | 39.7397  |
# |    85    |  54.2556  | 14.9063  |  4.944   | 0.0  | 0.0 | 0.0  |  7.8114  |
# |    86    |  47.1182  | 26.1921  |  47.076  | 0.0  | 0.0 | 0.0  |  0.9259  |
# |    87    |  13.1927  |  8.5717  | 14.4534  | 0.0  | 0.0 | 0.0  |  0.7033  |
# |    88    |  70.5532  |  27.089  | 51.4284  | 0.0  | 0.0 | 0.0  |  4.3061  |
# |    89    |  147.0591 | 46.2118  |  42.659  | 0.0  | 0.0 | 0.0  | -7.5955  |
# |    90    |  51.5839  | 21.0783  |  7.7476  | 0.0  | 0.0 | 0.0  |  1.2255  |
# |    91    |  91.0647  | 31.8924  |  0.5508  | 0.0  | 0.0 | 0.0  |  6.5224  |
# |    92    |   9.1853  | 11.3885  |  8.7538  | 0.0  | 0.0 | 0.0  |  5.3959  |
# |    93    |  306.7982 | 128.2457 | 233.3826 | 0.0  | 0.0 | 0.0  | 27.5445  |
# |    94    |  59.4127  | 39.8936  |  0.0689  | 0.0  | 0.0 | 0.0  |  1.7616  |
# |    95    |   92.044  | 59.5356  | 23.2509  | 0.0  | 0.0 | 0.0  |  3.1725  |
# |    96    |  61.5962  | 14.5757  |  0.6419  | 0.0  | 0.0 | 0.0  | -3.3006  |
# |    97    |  189.2221 | 177.0583 | 97.2818  | 0.0  | 0.0 | 0.0  | 24.2376  |
# |    98    |  111.2096 | 30.3021  |  0.8375  | 0.0  | 0.0 | 0.0  | -9.8482  |
# |    99    |  26.4995  | 20.8429  |  0.2437  | 0.0  | 0.0 | 0.0  |  2.3314  |
# | Overall  |  119.9363 | 43.9621  | 44.2823  | 0.01 | 0.0 | 0.08 |  6.1078  |
# +----------+-----------+----------+----------+------+-----+------+----------+
# (RolloutWorker pid=39472) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/transforms3d/quaternions.py:26: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=39472) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=39472)   _MAX_FLOAT = np.maximum_sctype(np.float)
# (RolloutWorker pid=39472) /home/pronton/rl/l5kit/l5kit/l5kit/data/map_api.py:399: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=39472) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=39472)   lanes_bounds = np.empty((0, 2, 2), dtype=np.float)  # [(X_MIN, Y_MIN), (X_MAX, Y_MAX)]
# (RolloutWorker pid=39472) 2023-01-02 14:53:25,222	WARNING env.py:147 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=39472) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/gym/utils/seeding.py:47: DeprecationWarning: WARN: Function `rng.randint(low, [high, size, dtype])` is marked as deprecated and will be removed in the future. Please use `rng.integers(low, [high, size, dtype])` instead.
# (RolloutWorker pid=39472)   deprecation(
# (RolloutWorker pid=39472) /home/pronton/rl/l5kit/l5kit/l5kit/data/zarr_dataset.py:213: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=39472)   dataset = ChunkedDataset("")
# (RolloutWorker pid=39472) /home/pronton/rl/l5kit/l5kit/l5kit/simulation/utils.py:107: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=39472)   new_dataset = ChunkedDataset("")
# (RolloutWorker pid=39472) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:71: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=39472) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=39472)   coords = coords.astype(np.int)
# (RolloutWorker pid=39472) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:140: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# (RolloutWorker pid=39472) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=39472)   lanes_mask: Dict[str, np.ndarray] = defaultdict(lambda: np.zeros(len(lane_indices) * 2, dtype=np.bool))
# (RolloutWorker pid=39472) 2023-01-02 14:53:25,444	WARNING catalog.py:637 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# (raylet) [2023-01-02 14:53:29,039 E 31490 31490] (raylet) node_manager.cc:3097: 1 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 60735a255ff7f4f5e66b815ede73b78545f2948f32eb469823abbcac, IP: 192.168.1.4) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 192.168.1.4`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (RolloutWorker pid=44503) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/transforms3d/quaternions.py:26: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=44503) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=44503)   _MAX_FLOAT = np.maximum_sctype(np.float)
# (RolloutWorker pid=44503) /home/pronton/rl/l5kit/l5kit/l5kit/data/map_api.py:399: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=44503) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=44503)   lanes_bounds = np.empty((0, 2, 2), dtype=np.float)  # [(X_MIN, Y_MIN), (X_MAX, Y_MAX)]
# (RolloutWorker pid=44503) 2023-01-02 16:53:58,119	WARNING env.py:147 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=44503) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/gym/utils/seeding.py:47: DeprecationWarning: WARN: Function `rng.randint(low, [high, size, dtype])` is marked as deprecated and will be removed in the future. Please use `rng.integers(low, [high, size, dtype])` instead.
# (RolloutWorker pid=44503)   deprecation(
# (RolloutWorker pid=44503) /home/pronton/rl/l5kit/l5kit/l5kit/data/zarr_dataset.py:213: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=44503)   dataset = ChunkedDataset("")
# (RolloutWorker pid=44503) /home/pronton/rl/l5kit/l5kit/l5kit/simulation/utils.py:107: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=44503)   new_dataset = ChunkedDataset("")
# (RolloutWorker pid=44503) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:71: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=44503) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=44503)   coords = coords.astype(np.int)
# (RolloutWorker pid=44503) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:140: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# (RolloutWorker pid=44503) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=44503)   lanes_mask: Dict[str, np.ndarray] = defaultdict(lambda: np.zeros(len(lane_indices) * 2, dtype=np.bool))
# (RolloutWorker pid=44503) 2023-01-02 16:53:58,440	WARNING catalog.py:637 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# (RolloutWorker pid=44652) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/transforms3d/quaternions.py:26: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=44652) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=44652)   _MAX_FLOAT = np.maximum_sctype(np.float)
# (RolloutWorker pid=44652) /home/pronton/rl/l5kit/l5kit/l5kit/data/map_api.py:399: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=44652) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=44652)   lanes_bounds = np.empty((0, 2, 2), dtype=np.float)  # [(X_MIN, Y_MIN), (X_MAX, Y_MAX)]
# (RolloutWorker pid=44652) 2023-01-02 16:54:29,104	WARNING env.py:147 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=44652) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/gym/utils/seeding.py:47: DeprecationWarning: WARN: Function `rng.randint(low, [high, size, dtype])` is marked as deprecated and will be removed in the future. Please use `rng.integers(low, [high, size, dtype])` instead.
# (RolloutWorker pid=44652)   deprecation(
# (RolloutWorker pid=44652) /home/pronton/rl/l5kit/l5kit/l5kit/data/zarr_dataset.py:213: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=44652)   dataset = ChunkedDataset("")
# (RolloutWorker pid=44652) /home/pronton/rl/l5kit/l5kit/l5kit/simulation/utils.py:107: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=44652)   new_dataset = ChunkedDataset("")
# (raylet) [2023-01-02 16:54:29,299 E 31490 31490] (raylet) node_manager.cc:3097: 2 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 60735a255ff7f4f5e66b815ede73b78545f2948f32eb469823abbcac, IP: 192.168.1.4) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 192.168.1.4`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (RolloutWorker pid=44652) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:71: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=44652) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=44652)   coords = coords.astype(np.int)
# (RolloutWorker pid=44652) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:140: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# (RolloutWorker pid=44652) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=44652)   lanes_mask: Dict[str, np.ndarray] = defaultdict(lambda: np.zeros(len(lane_indices) * 2, dtype=np.bool))
# (RolloutWorker pid=44652) 2023-01-02 16:54:29,347	WARNING catalog.py:637 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# (raylet) [2023-01-02 16:56:29,304 E 31490 31490] (raylet) node_manager.cc:3097: 7 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 60735a255ff7f4f5e66b815ede73b78545f2948f32eb469823abbcac, IP: 192.168.1.4) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 192.168.1.4`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (RolloutWorker pid=45255) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/transforms3d/quaternions.py:26: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=45255) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=45255)   _MAX_FLOAT = np.maximum_sctype(np.float)
# (RolloutWorker pid=45255) /home/pronton/rl/l5kit/l5kit/l5kit/data/map_api.py:399: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=45255) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=45255)   lanes_bounds = np.empty((0, 2, 2), dtype=np.float)  # [(X_MIN, Y_MIN), (X_MAX, Y_MAX)]
# (RolloutWorker pid=45255) 2023-01-02 16:56:38,127	WARNING env.py:147 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=45255) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/gym/utils/seeding.py:47: DeprecationWarning: WARN: Function `rng.randint(low, [high, size, dtype])` is marked as deprecated and will be removed in the future. Please use `rng.integers(low, [high, size, dtype])` instead.
# (RolloutWorker pid=45255)   deprecation(
# (RolloutWorker pid=45255) /home/pronton/rl/l5kit/l5kit/l5kit/data/zarr_dataset.py:213: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=45255)   dataset = ChunkedDataset("")
# (RolloutWorker pid=45255) /home/pronton/rl/l5kit/l5kit/l5kit/simulation/utils.py:107: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=45255)   new_dataset = ChunkedDataset("")
# (RolloutWorker pid=45255) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:71: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=45255) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=45255)   coords = coords.astype(np.int)
# (RolloutWorker pid=45255) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:140: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# (RolloutWorker pid=45255) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=45255)   lanes_mask: Dict[str, np.ndarray] = defaultdict(lambda: np.zeros(len(lane_indices) * 2, dtype=np.bool))
# (RolloutWorker pid=45255) 2023-01-02 16:56:38,384	WARNING catalog.py:637 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# (RolloutWorker pid=46023) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/transforms3d/quaternions.py:26: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=46023) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=46023)   _MAX_FLOAT = np.maximum_sctype(np.float)
# (RolloutWorker pid=46023) /home/pronton/rl/l5kit/l5kit/l5kit/data/map_api.py:399: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=46023) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=46023)   lanes_bounds = np.empty((0, 2, 2), dtype=np.float)  # [(X_MIN, Y_MIN), (X_MAX, Y_MAX)]
# (RolloutWorker pid=46023) 2023-01-02 17:01:41,705	WARNING env.py:147 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=46023) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/gym/utils/seeding.py:47: DeprecationWarning: WARN: Function `rng.randint(low, [high, size, dtype])` is marked as deprecated and will be removed in the future. Please use `rng.integers(low, [high, size, dtype])` instead.
# (RolloutWorker pid=46023)   deprecation(
# (RolloutWorker pid=46023) /home/pronton/rl/l5kit/l5kit/l5kit/data/zarr_dataset.py:213: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=46023)   dataset = ChunkedDataset("")
# (RolloutWorker pid=46023) /home/pronton/rl/l5kit/l5kit/l5kit/simulation/utils.py:107: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=46023)   new_dataset = ChunkedDataset("")
# (RolloutWorker pid=46023) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:71: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=46023) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=46023)   coords = coords.astype(np.int)
# (RolloutWorker pid=46023) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:140: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# (RolloutWorker pid=46023) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=46023)   lanes_mask: Dict[str, np.ndarray] = defaultdict(lambda: np.zeros(len(lane_indices) * 2, dtype=np.bool))
# (RolloutWorker pid=46023) 2023-01-02 17:01:41,971	WARNING catalog.py:637 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# (raylet) [2023-01-02 17:02:29,319 E 31490 31490] (raylet) node_manager.cc:3097: 1 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 60735a255ff7f4f5e66b815ede73b78545f2948f32eb469823abbcac, IP: 192.168.1.4) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 192.168.1.4`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (RolloutWorker pid=46190) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/transforms3d/quaternions.py:26: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=46190) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=46190)   _MAX_FLOAT = np.maximum_sctype(np.float)
# (RolloutWorker pid=46190) /home/pronton/rl/l5kit/l5kit/l5kit/data/map_api.py:399: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=46190) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=46190)   lanes_bounds = np.empty((0, 2, 2), dtype=np.float)  # [(X_MIN, Y_MIN), (X_MAX, Y_MAX)]
# (RolloutWorker pid=46190) 2023-01-02 17:02:48,046	WARNING env.py:147 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=46190) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/gym/utils/seeding.py:47: DeprecationWarning: WARN: Function `rng.randint(low, [high, size, dtype])` is marked as deprecated and will be removed in the future. Please use `rng.integers(low, [high, size, dtype])` instead.
# (RolloutWorker pid=46190)   deprecation(
# (RolloutWorker pid=46190) /home/pronton/rl/l5kit/l5kit/l5kit/data/zarr_dataset.py:213: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=46190)   dataset = ChunkedDataset("")
# (RolloutWorker pid=46190) /home/pronton/rl/l5kit/l5kit/l5kit/simulation/utils.py:107: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=46190)   new_dataset = ChunkedDataset("")
# (RolloutWorker pid=46190) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:71: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=46190) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=46190)   coords = coords.astype(np.int)
# (RolloutWorker pid=46190) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:140: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# (RolloutWorker pid=46190) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=46190)   lanes_mask: Dict[str, np.ndarray] = defaultdict(lambda: np.zeros(len(lane_indices) * 2, dtype=np.bool))
# (RolloutWorker pid=46190) 2023-01-02 17:02:48,285	WARNING catalog.py:637 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# (raylet) [2023-01-02 17:03:29,320 E 31490 31490] (raylet) node_manager.cc:3097: 1 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 60735a255ff7f4f5e66b815ede73b78545f2948f32eb469823abbcac, IP: 192.168.1.4) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 192.168.1.4`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (RolloutWorker pid=46698) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/transforms3d/quaternions.py:26: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=46698) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=46698)   _MAX_FLOAT = np.maximum_sctype(np.float)
# (RolloutWorker pid=46698) /home/pronton/rl/l5kit/l5kit/l5kit/data/map_api.py:399: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=46698) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=46698)   lanes_bounds = np.empty((0, 2, 2), dtype=np.float)  # [(X_MIN, Y_MIN), (X_MAX, Y_MAX)]
# (RolloutWorker pid=46698) 2023-01-02 17:04:57,920	WARNING env.py:147 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=46698) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/gym/utils/seeding.py:47: DeprecationWarning: WARN: Function `rng.randint(low, [high, size, dtype])` is marked as deprecated and will be removed in the future. Please use `rng.integers(low, [high, size, dtype])` instead.
# (RolloutWorker pid=46698)   deprecation(
# (RolloutWorker pid=46698) /home/pronton/rl/l5kit/l5kit/l5kit/data/zarr_dataset.py:213: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=46698)   dataset = ChunkedDataset("")
# (RolloutWorker pid=46698) /home/pronton/rl/l5kit/l5kit/l5kit/simulation/utils.py:107: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=46698)   new_dataset = ChunkedDataset("")
# (RolloutWorker pid=46698) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:71: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=46698) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=46698)   coords = coords.astype(np.int)
# (RolloutWorker pid=46698) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:140: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# (RolloutWorker pid=46698) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=46698)   lanes_mask: Dict[str, np.ndarray] = defaultdict(lambda: np.zeros(len(lane_indices) * 2, dtype=np.bool))
# (RolloutWorker pid=46698) 2023-01-02 17:04:58,231	WARNING catalog.py:637 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# (raylet) [2023-01-02 17:05:29,324 E 31490 31490] (raylet) node_manager.cc:3097: 1 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 60735a255ff7f4f5e66b815ede73b78545f2948f32eb469823abbcac, IP: 192.168.1.4) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 192.168.1.4`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (RolloutWorker pid=47094) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/transforms3d/quaternions.py:26: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=47094) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=47094)   _MAX_FLOAT = np.maximum_sctype(np.float)
# (RolloutWorker pid=47094) /home/pronton/rl/l5kit/l5kit/l5kit/data/map_api.py:399: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=47094) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=47094)   lanes_bounds = np.empty((0, 2, 2), dtype=np.float)  # [(X_MIN, Y_MIN), (X_MAX, Y_MAX)]
# (RolloutWorker pid=47094) 2023-01-02 17:07:47,815	WARNING env.py:147 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=47094) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/gym/utils/seeding.py:47: DeprecationWarning: WARN: Function `rng.randint(low, [high, size, dtype])` is marked as deprecated and will be removed in the future. Please use `rng.integers(low, [high, size, dtype])` instead.
# (RolloutWorker pid=47094)   deprecation(
# (RolloutWorker pid=47094) /home/pronton/rl/l5kit/l5kit/l5kit/data/zarr_dataset.py:213: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=47094)   dataset = ChunkedDataset("")
# (RolloutWorker pid=47094) /home/pronton/rl/l5kit/l5kit/l5kit/simulation/utils.py:107: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=47094)   new_dataset = ChunkedDataset("")
# (RolloutWorker pid=47094) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:71: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=47094) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=47094)   coords = coords.astype(np.int)
# (RolloutWorker pid=47094) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:140: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# (RolloutWorker pid=47094) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=47094)   lanes_mask: Dict[str, np.ndarray] = defaultdict(lambda: np.zeros(len(lane_indices) * 2, dtype=np.bool))
# (RolloutWorker pid=47094) 2023-01-02 17:07:48,082	WARNING catalog.py:637 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# (raylet) [2023-01-02 17:08:29,343 E 31490 31490] (raylet) node_manager.cc:3097: 4 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 60735a255ff7f4f5e66b815ede73b78545f2948f32eb469823abbcac, IP: 192.168.1.4) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 192.168.1.4`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (RolloutWorker pid=48655) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/transforms3d/quaternions.py:26: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=48655) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=48655)   _MAX_FLOAT = np.maximum_sctype(np.float)
# (RolloutWorker pid=48655) /home/pronton/rl/l5kit/l5kit/l5kit/data/map_api.py:399: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=48655) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=48655)   lanes_bounds = np.empty((0, 2, 2), dtype=np.float)  # [(X_MIN, Y_MIN), (X_MAX, Y_MAX)]
# (RolloutWorker pid=48655) 2023-01-02 17:23:13,625	WARNING env.py:147 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=48655) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/gym/utils/seeding.py:47: DeprecationWarning: WARN: Function `rng.randint(low, [high, size, dtype])` is marked as deprecated and will be removed in the future. Please use `rng.integers(low, [high, size, dtype])` instead.
# (RolloutWorker pid=48655)   deprecation(
# (RolloutWorker pid=48655) /home/pronton/rl/l5kit/l5kit/l5kit/data/zarr_dataset.py:213: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=48655)   dataset = ChunkedDataset("")
# (RolloutWorker pid=48655) /home/pronton/rl/l5kit/l5kit/l5kit/simulation/utils.py:107: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=48655)   new_dataset = ChunkedDataset("")
# ...
# (RolloutWorker pid=50369) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=50369)   lanes_mask: Dict[str, np.ndarray] = defaultdict(lambda: np.zeros(len(lane_indices) * 2, dtype=np.bool))
# (RolloutWorker pid=50369) 2023-01-02 17:32:02,610	WARNING catalog.py:637 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# (raylet) [2023-01-02 17:32:29,389 E 31490 31490] (raylet) node_manager.cc:3097: 2 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 60735a255ff7f4f5e66b815ede73b78545f2948f32eb469823abbcac, IP: 192.168.1.4) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 192.168.1.4`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (RolloutWorker pid=50527) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/transforms3d/quaternions.py:26: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=50527) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=50527)   _MAX_FLOAT = np.maximum_sctype(np.float)
# (RolloutWorker pid=50527) /home/pronton/rl/l5kit/l5kit/l5kit/data/map_api.py:399: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=50527) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=50527)   lanes_bounds = np.empty((0, 2, 2), dtype=np.float)  # [(X_MIN, Y_MIN), (X_MAX, Y_MAX)]
# (RolloutWorker pid=50527) 2023-01-02 17:32:51,638	WARNING env.py:147 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=50527) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/gym/utils/seeding.py:47: DeprecationWarning: WARN: Function `rng.randint(low, [high, size, dtype])` is marked as deprecated and will be removed in the future. Please use `rng.integers(low, [high, size, dtype])` instead.
# (RolloutWorker pid=50527)   deprecation(
# (RolloutWorker pid=50527) /home/pronton/rl/l5kit/l5kit/l5kit/data/zarr_dataset.py:213: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=50527)   dataset = ChunkedDataset("")
# (RolloutWorker pid=50527) /home/pronton/rl/l5kit/l5kit/l5kit/simulation/utils.py:107: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=50527)   new_dataset = ChunkedDataset("")
# (RolloutWorker pid=50527) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:71: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=50527) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=50527)   coords = coords.astype(np.int)
# (RolloutWorker pid=50527) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:140: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# (RolloutWorker pid=50527) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=50527)   lanes_mask: Dict[str, np.ndarray] = defaultdict(lambda: np.zeros(len(lane_indices) * 2, dtype=np.bool))
# (RolloutWorker pid=50527) 2023-01-02 17:32:51,847	WARNING catalog.py:637 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# (raylet) [2023-01-02 17:33:29,392 E 31490 31490] (raylet) node_manager.cc:3097: 1 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 60735a255ff7f4f5e66b815ede73b78545f2948f32eb469823abbcac, IP: 192.168.1.4) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 192.168.1.4`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (RolloutWorker pid=51571) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/transforms3d/quaternions.py:26: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=51571) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=51571)   _MAX_FLOAT = np.maximum_sctype(np.float)
# (RolloutWorker pid=51571) /home/pronton/rl/l5kit/l5kit/l5kit/data/map_api.py:399: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=51571) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=51571)   lanes_bounds = np.empty((0, 2, 2), dtype=np.float)  # [(X_MIN, Y_MIN), (X_MAX, Y_MAX)]
# (RolloutWorker pid=51571) 2023-01-02 17:44:25,453	WARNING env.py:147 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=51571) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/gym/utils/seeding.py:47: DeprecationWarning: WARN: Function `rng.randint(low, [high, size, dtype])` is marked as deprecated and will be removed in the future. Please use `rng.integers(low, [high, size, dtype])` instead.
# (RolloutWorker pid=51571)   deprecation(
# (RolloutWorker pid=51571) /home/pronton/rl/l5kit/l5kit/l5kit/data/zarr_dataset.py:213: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=51571)   dataset = ChunkedDataset("")
# (RolloutWorker pid=51571) /home/pronton/rl/l5kit/l5kit/l5kit/simulation/utils.py:107: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=51571)   new_dataset = ChunkedDataset("")
# (RolloutWorker pid=51571) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:71: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=51571) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=51571)   coords = coords.astype(np.int)
# (RolloutWorker pid=51571) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:140: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# (RolloutWorker pid=51571) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=51571)   lanes_mask: Dict[str, np.ndarray] = defaultdict(lambda: np.zeros(len(lane_indices) * 2, dtype=np.bool))
# (RolloutWorker pid=51571) 2023-01-02 17:44:25,793	WARNING catalog.py:637 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# (raylet) [2023-01-02 17:44:29,418 E 31490 31490] (raylet) node_manager.cc:3097: 1 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 60735a255ff7f4f5e66b815ede73b78545f2948f32eb469823abbcac, IP: 192.168.1.4) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 192.168.1.4`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (RolloutWorker pid=51749) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/transforms3d/quaternions.py:26: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=51749) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=51749)   _MAX_FLOAT = np.maximum_sctype(np.float)
# (RolloutWorker pid=51749) /home/pronton/rl/l5kit/l5kit/l5kit/data/map_api.py:399: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# (RolloutWorker pid=51749) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=51749)   lanes_bounds = np.empty((0, 2, 2), dtype=np.float)  # [(X_MIN, Y_MIN), (X_MAX, Y_MAX)]
# (RolloutWorker pid=51749) 2023-01-02 17:45:24,136	WARNING env.py:147 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=51749) /home/pronton/.local/share/virtualenvs/l5kit-nr_j5XnQ/lib/python3.8/site-packages/gym/utils/seeding.py:47: DeprecationWarning: WARN: Function `rng.randint(low, [high, size, dtype])` is marked as deprecated and will be removed in the future. Please use `rng.integers(low, [high, size, dtype])` instead.
# (RolloutWorker pid=51749)   deprecation(
# (RolloutWorker pid=51749) /home/pronton/rl/l5kit/l5kit/l5kit/data/zarr_dataset.py:213: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=51749)   dataset = ChunkedDataset("")
# (RolloutWorker pid=51749) /home/pronton/rl/l5kit/l5kit/l5kit/simulation/utils.py:107: RuntimeWarning: zarr dataset path should end with .zarr (for now). Open will fail for this dataset!
# (RolloutWorker pid=51749)   new_dataset = ChunkedDataset("")
# (RolloutWorker pid=51749) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:71: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=51749) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=51749)   coords = coords.astype(np.int)
# (RolloutWorker pid=51749) /home/pronton/rl/l5kit/l5kit/l5kit/rasterization/semantic_rasterizer.py:140: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# (RolloutWorker pid=51749) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=51749)   lanes_mask: Dict[str, np.ndarray] = defaultdict(lambda: np.zeros(len(lane_indices) * 2, dtype=np.bool))
# (RolloutWorker pid=51749) 2023-01-02 17:45:24,347	WARNING catalog.py:637 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# (raylet) [2023-01-02 17:45:29,423 E 31490 31490] (raylet) node_manager.cc:3097: 1 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 60735a255ff7f4f5e66b815ede73b78545f2948f32eb469823abbcac, IP: 192.168.1.4) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 192.168.1.4`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
